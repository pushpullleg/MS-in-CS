# %% [markdown]
# # Week 2

# %% [markdown]
# Dataframe basics and basic fucntions

# %%
import pandas as pd

# %%
df = pd.read_csv('nyc_weather.csv')

# %% [markdown]
# # Indexing and Slicing

# %% [markdown]
# ## Just rows 2 to 4
#
# We use slicing 2:5 where 5 is not included

# %%
df[2:5]
# Out:
#       EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2  1/3/16           40        21        47                 29.86
# 3  1/4/16           25         9        44                 30.05
# 4  1/5/16           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 2             277
# 3             345
# 4             333

# %%
df
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/16           38        23        52                 30.03
# 1    1/2/16           36        18        46                 30.02
# 2    1/3/16           40        21        47                 29.86
# 3    1/4/16           25         9        44                 30.05
# 4    1/5/16           20        -3        41                 30.57
# 5    1/6/16           33         4        35                 30.50
# 6    1/7/16           39        11        33                 30.28
# 7    1/8/16           39        29        64                 30.20
# 8    1/9/16           44        38        77                 30.16
# 9   1/10/16           50        46        71                 29.59
# 10  1/11/16           33         8        37                 29.92
# 11  1/12/16           35        15        53                 29.85
# 12  1/13/16           26         4        42                 29.94
# ...

# %% [markdown]
# # Columns
#
# Print the columns in the dataframe

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
#df.Events  or 
df['Events'] # both are same
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8         Rain
# 9         Rain
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15        Rain
# 16    Fog-Snow
# 17        snow
# 18         NaN
# 19         NaN
# 20         NaN
# 21        Snow
# 22    Fog-Snow
# 23        Snow
# 24         NaN
# 25         NaN
# 26        Rain
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# Name: Events, dtype: object

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %% [markdown]
# What type of series this is ?

# %%
type(df['Events'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# **How do you print selected columns**

# %%
df[['Events','EST']]
# Out:
#       Events      EST
# 0        NaN   1/1/16
# 1        NaN   1/2/16
# 2        NaN   1/3/16
# 3        NaN   1/4/16
# 4        NaN   1/5/16
# 5        NaN   1/6/16
# 6        NaN   1/7/16
# 7        NaN   1/8/16
# 8       Rain   1/9/16
# 9       Rain  1/10/16
# 10       NaN  1/11/16
# 11       NaN  1/12/16
# 12       NaN  1/13/16
# 13       NaN  1/14/16
# 14       NaN  1/15/16
# 15      Rain  1/16/16
# 16  Fog-Snow  1/17/16
# 17      snow  1/18/16
# 18       NaN  1/19/16
# 19       NaN  1/20/16
# 20       NaN  1/21/16
# 21      Snow  1/22/16
# 22  Fog-Snow  1/23/16
# 23      Snow  1/24/16
# 24       NaN  1/25/16
# 25       NaN  1/26/16
# 26      Rain  1/27/16
# 27       NaN  1/28/16
# 28       NaN  1/29/16
# 29       NaN  1/30/16
# 30       NaN  1/31/16

# %% [markdown]
# How to find the maximum in a given column?

# %%
df.Temperature.max()
# Out:
# 50

# %%
df['Temperature'].max()
# Out:
# 50

# %% [markdown]
# ## How to quickly print Stastics of your data ?

# %%
df[2:10]
#df.Temperature.describe 
# This didnt work for this , probabaly if it has only few columns then it might
# Out:
#        EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2   1/3/16           40        21        47                 29.86
# 3   1/4/16           25         9        44                 30.05
# 4   1/5/16           20        -3        41                 30.57
# 5   1/6/16           33         4        35                 30.50
# 6   1/7/16           39        11        33                 30.28
# 7   1/8/16           39        29        64                 30.20
# 8   1/9/16           44        38        77                 30.16
# 9  1/10/16           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
# 5               10           4.0               0           0    NaN
# ...

# %% [markdown]
# ##  Dataframes works as SQL, wherein you can enter the condition

# %%
df[df.Temperature>45]
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9   1/10/16           50        46        71                 29.59
# 15  1/16/16           47        37        70                 29.52
# 30  1/31/16           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                 4           NaN             1.8           7   Rain
# 15                8           7.0            0.24           7   Rain
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 9              109
# 15             340
# 30             241

# %%
df[df.Temperature==df.Temperature.max()]
# Out:
#        EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/16           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           NaN             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %% [markdown]
# ## Where do we find other functions?
#
# pandas series functions gives you lot of other documentation

# %% [markdown]
# ## How to change from internal index (default)

# %%
df.set_index('EST')
# this is not square brackets
# Out:
#          Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/1/16            38        23        52                 30.03
# 1/2/16            36        18        46                 30.02
# 1/3/16            40        21        47                 29.86
# 1/4/16            25         9        44                 30.05
# 1/5/16            20        -3        41                 30.57
# 1/6/16            33         4        35                 30.50
# 1/7/16            39        11        33                 30.28
# 1/8/16            39        29        64                 30.20
# 1/9/16            44        38        77                 30.16
# 1/10/16           50        46        71                 29.59
# 1/11/16           33         8        37                 29.92
# 1/12/16           35        15        53                 29.85
# 1/13/16           26         4        42                 29.94
# 1/14/16           30        12        47                 29.95
# ...

# %% [markdown]
# Setting the index gives us option of locating the date

# %%
df.loc['1/4/2017']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '1/4/2017'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 df.loc['1/4/2017']
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
# ...

# %% [markdown]
# But This gives you error ! why ?
# because index we set is temporary only ,the set_index gives me new dataframe
# it doesnt modify the original dataframe. then how do we change it to default?

# %%
df.set_index('EST', inplace =True)
df
# Out:
#          Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/1/16            38        23        52                 30.03
# 1/2/16            36        18        46                 30.02
# 1/3/16            40        21        47                 29.86
# 1/4/16            25         9        44                 30.05
# 1/5/16            20        -3        41                 30.57
# 1/6/16            33         4        35                 30.50
# 1/7/16            39        11        33                 30.28
# 1/8/16            39        29        64                 30.20
# 1/9/16            44        38        77                 30.16
# 1/10/16           50        46        71                 29.59
# 1/11/16           33         8        37                 29.92
# 1/12/16           35        15        53                 29.85
# 1/13/16           26         4        42                 29.94
# 1/14/16           30        12        47                 29.95
# ...

# %%
df.loc['1/1/16']
# Out:
# Temperature                38
# DewPoint                   23
# Humidity                   52
# Sea Level PressureIn    30.03
# VisibilityMiles            10
# WindSpeedMPH              8.0
# PrecipitationIn             0
# CloudCover                  5
# Events                    NaN
# WindDirDegrees            281
# Name: 1/1/16, dtype: object

# %% [markdown]
# # How to reset index ?

# %%
df.reset_index(inplace=True)
df
# Out:
#     index      EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0       0   1/1/16           38        23        52                 30.03
# 1       1   1/2/16           36        18        46                 30.02
# 2       2   1/3/16           40        21        47                 29.86
# 3       3   1/4/16           25         9        44                 30.05
# 4       4   1/5/16           20        -3        41                 30.57
# 5       5   1/6/16           33         4        35                 30.50
# 6       6   1/7/16           39        11        33                 30.28
# 7       7   1/8/16           39        29        64                 30.20
# 8       8   1/9/16           44        38        77                 30.16
# 9       9  1/10/16           50        46        71                 29.59
# 10     10  1/11/16           33         8        37                 29.92
# 11     11  1/12/16           35        15        53                 29.85
# ...

# %%
df.set_index('Temperature',inplace=True)

# %%
df
# Out:
#              index      EST  DewPoint  Humidity  Sea Level PressureIn  \
# Temperature
# 38               0   1/1/16        23        52                 30.03
# 36               1   1/2/16        18        46                 30.02
# 40               2   1/3/16        21        47                 29.86
# 25               3   1/4/16         9        44                 30.05
# 20               4   1/5/16        -3        41                 30.57
# 33               5   1/6/16         4        35                 30.50
# 39               6   1/7/16        11        33                 30.28
# 39               7   1/8/16        29        64                 30.20
# 44               8   1/9/16        38        77                 30.16
# 50               9  1/10/16        46        71                 29.59
# 33              10  1/11/16         8        37                 29.92
# 35              11  1/12/16        15        53                 29.85
# ...
